# %%
import sys
sys.path.append("C:\scripts\Imaging analysis")
import numpy as np
import scipy.io as scio
import matplotlib.pyplot as plt
import session
from matplotlib.pyplot import figure
from numpy import concatenate as cat
from sklearn.preprocessing import normalize
import quality
import bootstrap

# %% [markdown]
# ### Aim 2 data

# %%
path = r'H:\\data\\BAYLORCW039\\python\\2024_04_17'
d1 = bootstrap.Sample(path)

scores1, sem1 = d1.run_iter_log_timesteps(bias=False)
# np.save(r'F:\data\BAYLORCW021\python\2023_04_06\choice_decoder_bias.npy', np.array([scores1, sem1]))

plt.plot(scores1)
plt.fill_between(x, scores1 - sem1, 
         scores1 + sem1,
         color=['#b4b2dc'])
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 scores1
#
# NameError: name 'scores1' is not defined

# %%
plt.plot(scores1)
plt.fill_between(x, scores1 - sem1, 
         scores1 + sem1,
         color=['#b4b2dc'])
plt.show()

# %%
path = r'F:\data\BAYLORCW021\python\2023_04_06'
d1 = bootstrap.Sample(path)

scores1, sem1 = d1.run_iter_log_timesteps(bias=True)
np.save(r'F:\data\BAYLORCW021\python\2023_04_06\choice_decoder_bias.npy', np.array([scores1, sem1]))

plt.plot(scores1)
plt.fill_between(x, scores1 - sem1, 
         scores1 + sem1,
         color=['#b4b2dc'])
plt.show()
# Out:
# Minimum cutoff is 46
# Water leak trials: [24 25 96]
# New number of good trials: 379
# ##### TIMESTEP 0 #######
# ##### TIMESTEP 1 #######
# ##### TIMESTEP 2 #######
# ##### TIMESTEP 3 #######
# ##### TIMESTEP 4 #######
# ##### TIMESTEP 5 #######
# ##### TIMESTEP 6 #######
# ##### TIMESTEP 7 #######
# ##### TIMESTEP 8 #######
# ##### TIMESTEP 9 #######
# ##### TIMESTEP 10 #######
# ##### TIMESTEP 11 #######
# ##### TIMESTEP 12 #######
# ##### TIMESTEP 13 #######
# ##### TIMESTEP 14 #######
# ##### TIMESTEP 15 #######
# ##### TIMESTEP 16 #######
# ##### TIMESTEP 17 #######
# ##### TIMESTEP 18 #######
# ##### TIMESTEP 19 #######
# ##### TIMESTEP 20 #######
# ##### TIMESTEP 21 #######
# ##### TIMESTEP 22 #######
# ##### TIMESTEP 23 #######
# ##### TIMESTEP 24 #######
# ##### TIMESTEP 25 #######
# ##### TIMESTEP 26 #######
# ##### TIMESTEP 27 #######
# ##### TIMESTEP 28 #######
# ##### TIMESTEP 29 #######
# ##### TIMESTEP 30 #######
# ##### TIMESTEP 31 #######
# ...

# %%
path = r'F:\data\BAYLORCW021\python\2023_04_27'
d1 = bootstrap.Sample(path)
# Out:
# Minimum cutoff is 46
# No water leak!

# %%
# d1.sample_trials(bias=True)
d1.find_bias_trials(state=2)
d1.path
# Out:
# 'F:\\data\\BAYLORCW021\\python\\2023_04_27'

# %%
path = r'F:\data\BAYLORCW021\python\2023_04_27'
d1 = bootstrap.Sample(path)

scores1, sem1 = d1.run_iter_log_timesteps(bias=True)
np.save(r'F:\data\BAYLORCW021\python\2023_04_27\choice_decoder_bias.npy', np.array([scores1, sem1]))

plt.plot(scores1)
plt.fill_between(x, scores1 - sem1, 
         scores1 + sem1,
         color=['#b4b2dc'])
plt.show()
# Out:
# Minimum cutoff is 46
# No water leak!
# ##### TIMESTEP 0 #######
# Traceback (most recent call last):
#
#   Cell In[32], line 4
#     scores1, sem1 = d1.run_iter_log_timesteps(bias=True)
#
#   File C:\scripts\Imaging analysis\bootstrap.py:189 in run_iter_log_timesteps
#     score = self.run_iter_logreg(time, len(self.n), sample, bias) # Use all neurons to train
#
#   File C:\scripts\Imaging analysis\bootstrap.py:175 in run_iter_logreg
#     lens = self.sample_trials(sample=sample, bias=bias)
#
#   File C:\scripts\Imaging analysis\bootstrap.py:75 in sample_trials
#     self.LL = np.random.choice(LL, size = correct, replace=False)
#
#   File mtrand.pyx:965 in numpy.random.mtrand.RandomState.choice
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
path = r'F:\data\BAYLORCW021\python\2023_04_06'
d1 = bootstrap.Sample(path)

scores1, sem1 = d1.run_iter_log_timesteps()
np.save(r'F:\data\BAYLORCW021\python\2023_04_06\choice_decoder.npy', np.array([scores1, sem1]))

plt.plot(scores1)
plt.fill_between(x, scores1 - sem1, 
         scores1 + sem1,
         color=['#b4b2dc'])
plt.show()
# Out:
# Minimum cutoff is 46
# Water leak trials: [24 25 96]
# New number of good trials: 379
# ##### TIMESTEP 0 #######
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
x = range(len(scores1))

# %%
scores1, sem1= np.array(scores1), np.array(sem1)

# %%
plt.plot(scores1)
plt.fill_between(x, scores1 - sem1, 
         scores1 + sem1,
         color=['#b4b2dc'])
plt.show()

# %%
path = r'F:\data\BAYLORCW021\python\2023_04_27'
d = bootstrap.Sample(path)

scores, sem = d.run_iter_log_timesteps()
np.save(r'F:\data\BAYLORCW021\python\2023_04_27\choice_decoder.npy', np.array([scores, sem]))
plt.plot(scores)
plt.fill_between(x, scores - sem, 
         scores + sem,
         color=['#b4b2dc'])
plt.show()
# Out:
# Minimum cutoff is 46
# ##### TIMESTEP 0 #######
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
np.save(r'F:\data\BAYLORCW021\python\2023_04_27\sample_decoder.npy', np.array([scores, sem]))

# %%
path = r'F:\data\BAYLORCW021\python\2023_04_27'
d = bootstrap.Sample(path)

scores, sem = d.run_iter_log_timesteps(sample=True)

plt.plot(scores)
plt.fill_between(x, scores - sem, 
         scores + sem,
         color=['#b4b2dc'])
plt.show()
# Out:
# Minimum cutoff is 46
# ##### TIMESTEP 0 #######
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
np.save(r'F:\data\BAYLORCW021\python\2023_04_06\sample_decoder.npy', np.array([scores1, sem1]))

# %%
path = r'F:\data\BAYLORCW021\python\2023_04_06'
d1 = bootstrap.Sample(path)

scores1, sem1 = d1.run_iter_log_timesteps(sample=True)

plt.plot(scores1)
plt.fill_between(x, scores1 - sem1, 
         scores1 + sem1,
         color=['#b4b2dc'])
plt.show()
# Out:
# Minimum cutoff is 46
# Water leak trials: [24 25 96]
# New number of good trials: 379
# ##### TIMESTEP 0 #######
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
